# %% [markdown]
# #สมาชิก

# %% [markdown]
# 1.   660710746 นางสาวสุนิตา กริชทิณวงศ์
# 2.   660710754 นางสาวฑิฆัมพร ทองสองแก้ว
# 3.   660710762 นางสาวนภสร เพชรศิริ

# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %%
import duckdb

# %%
con = duckdb.connect(database=':memory:', read_only=False)

# %%
query = "select * from 'netflix_titles.csv'"

# %%
netflix_result = con.execute(query).fetchdf()

# %%
netflix_result.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                                 cast        country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                               None           None
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
netflix_result.shape
# Out:
# (8807, 12)

# %%
netflix_result.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #ตัวอย่าง CTE แบบหลายขั้นตอน

# %%
query = """
WITH
-- ขั้นที่ 1: กรองข้อมูลพื้นฐาน
basic_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL
        AND date_added IS NOT NULL
        AND release_year IS NOT NULL
),

-- ขั้นที่ 2: สรุปข้อมูลตามประเทศ
country_summary AS (
    SELECT
        country,
        COUNT(*) as total_content,
        COUNT(CASE WHEN type = 'Movie' THEN 1 END) as movies,
        COUNT(CASE WHEN type = 'TV Show' THEN 1 END) as tv_shows,
        MIN(added_year) as first_year,
        MAX(added_year) as latest_year,
        ROUND(AVG(release_year), 1) as avg_release_year,
        COUNT(DISTINCT added_year) as active_years
    FROM basic_content
    GROUP BY country
    HAVING COUNT(*) >= 10  -- เฉพาะประเทศที่มีเนื้อหาอย่างน้อย 10 เรื่อง
),

-- ขั้นที่ 3: จัดอันดับประเทศ
ranked_countries AS (
    SELECT
        *,
        RANK() OVER (ORDER BY total_content DESC) as content_rank,
        ROUND(movies * 100.0 / total_content, 1) as movie_percentage,
        ROUND(tv_shows * 100.0 / total_content, 1) as tv_percentage,
        latest_year - first_year + 1 as span_years
    FROM country_summary
)

SELECT
    content_rank as rank,
    country,
    total_content,
    movies,
    tv_shows,
    movie_percentage as "movie_%",
    tv_percentage as "tv_%",
    first_year,
    latest_year,
    span_years,
    avg_release_year
FROM ranked_countries
ORDER BY total_content DESC;
"""

# Execute และแสดงผลสรุป
result = con.execute(query).fetchdf()

print("\n สรุปเทรนด์การเพิ่มเนื้อหาตามประเทศ (Top Countries)")
display(result)
# Out:
#  สรุปเทรนด์การเพิ่มเนื้อหาตามประเทศ (Top Countries)
#     rank                        country  total_content  movies  tv_shows  \
# 0      1                  United States           2812    2058       754
# 1      2                          India            972     893        79
# 2      3                 United Kingdom            418     206       212
# 3      4                          Japan            244      76       168
# 4      5                    South Korea            199      41       158
# 5      6                         Canada            181     122        59
# 6      7                          Spain            145      97        48
# 7      8                         France            124      75        49
# 8      9                         Mexico            110      70        40
# 9     10                          Egypt            106      92        14
# 10    11                         Turkey            105      76        29
# 11    12                        Nigeria             95      86         9
# 12    13                      Australia             86      39        47
# 13    14                         Taiwan             81      13        68
# 14    15                      Indonesia             79      77         2
# 15    16                         Brazil             77      50        27
# 16    17                    Philippines             75      73         2
# 17    17  United Kingdom, United States             75      63        12
# 18    19          United States, Canada             73      51        22
# 19    20                        Germany             67      47        20
# 20    21                          China             66      28        38
# 21    22                       Thailand             61      37        24
# 22    23                      Argentina             56      38        18
# 23    24                      Hong Kong             53      50         3
# 24    25  United States, United Kingdom             47      38         9
# 25    26                          Italy             45      32        13
# 26    26          Canada, United States             45      32        13
# 27    28                       Colombia             35      13        22
# 28    29                   South Africa             30      24         6
# 29    30                France, Belgium             27      24         3
# 30    31                         Poland             24      18         6
# 31    32                      Singapore             23       6        17
# 32    33                       Malaysia             22      16         6
# 33    34                    Netherlands             19      15         4
# 34    35                       Pakistan             18      14         4
# 35    36         United States, Germany             17      17         0
# 36    37           United States, Japan             16       6        10
# 37    37          United States, France             16      14         2
# 38    37               Hong Kong, China             16      16         0
# 39    40                         Russia             15       1        14
# 40    40                        Lebanon             15       9         6
# 41    42          United States, Mexico             14      11         3
# 42    42               China, Hong Kong             14      13         1
# 43    42           United Arab Emirates             14      13         1
# 44    42                          Chile             14      11         3
# 45    46       Australia, United States             13      10         3
# 46    46                         Sweden             13       5         8
# 47    46                        Denmark             13       5         8
# 48    46         Germany, United States             13      12         1
# 49    46                         Israel             13       5         8
# 50    46          Mexico, United States             13       7         6
# 51    52                    New Zealand             12      10         2
# 52    52           Japan, United States             12       9         3
# 53    54       United States, Australia             11      10         1
# 54    54                         Norway             11       6         5
# 55    56                        Ireland             10       7         3
# 56    56          France, United States             10       6         4
# 57    56           India, United States             10       9         1
#
#     movie_%  tv_%  first_year  latest_year  span_years  avg_release_year
# 0      73.2  26.8        2008         2021          14            2013.3
# 1      91.9   8.1        2016         2021           6            2012.0
# 2      49.3  50.7        2015         2021           7            2015.3
# 3      31.1  68.9        2015         2021           7            2014.3
# 4      20.6  79.4        2016         2021           6            2017.1
# 5      67.4  32.6        2013         2021           9            2016.4
# 6      66.9  33.1        2016         2021           6            2018.0
# 7      60.5  39.5        2015         2021           7            2016.8
# 8      63.6  36.4        2015         2021           7            2016.1
# 9      86.8  13.2        2018         2021           4            2009.0
# 10     72.4  27.6        2016         2021           6            2014.5
# 11     90.5   9.5        2015         2021           7            2017.2
# 12     45.3  54.7        2015         2021           7            2015.9
# 13     16.0  84.0        2016         2021           6            2014.4
# 14     97.5   2.5        2017         2021           5            2016.2
# 15     64.9  35.1        2016         2021           6            2018.2
# 16     97.3   2.7        2018         2021           4            2015.7
# 17     84.0  16.0        2014         2021           8            2010.5
# 18     69.9  30.1        2014         2021           8            2012.9
# 19     70.1  29.9        2015         2021           7            2017.5
# 20     42.4  57.6        2016         2021           6            2017.3
# 21     60.7  39.3        2017         2021           5            2014.8
# 22     67.9  32.1        2016         2021           6            2016.0
# 23     94.3   5.7        2016         2021           6            1998.0
# 24     80.9  19.1        2013         2021           9            2008.4
# 25     71.1  28.9        2016         2021           6            2017.2
# 26     71.1  28.9        2015         2021           7            2015.0
# 27     37.1  62.9        2016         2021           6            2017.4
# 28     80.0  20.0        2018         2021           4            2017.4
# 29     88.9  11.1        2015         2021           7            2016.1
# 30     75.0  25.0        2016         2021           6            2006.9
# 31     26.1  73.9        2017         2020           4            2013.2
# 32     72.7  27.3        2017         2021           5            2014.5
# 33     78.9  21.1        2016         2021           6            2017.5
# 34     77.8  22.2        2016         2019           4            2015.7
# 35    100.0   0.0        2019         2021           3            2005.3
# 36     37.5  62.5        2016         2021           6            2014.3
# 37     87.5  12.5        2016         2021           6            2010.2
# 38    100.0   0.0        2016         2020           5            2009.7
# 39      6.7  93.3        2017         2021           5            2016.5
# 40     60.0  40.0        2018         2021           4            2012.9
# 41     78.6  21.4        2012         2021          10            2011.9
# 42     92.9   7.1        2016         2021           6            2015.4
# 43     92.9   7.1        2017         2021           5            2018.0
# 44     78.6  21.4        2017         2020           4            2016.6
# 45     76.9  23.1        2017         2021           5            2010.1
# 46     38.5  61.5        2016         2021           6            2018.7
# 47     38.5  61.5        2009         2021          13            2016.1
# 48     92.3   7.7        2017         2021           5            2009.0
# 49     38.5  61.5        2016         2021           6            2017.2
# 50     53.8  46.2        2017         2021           5            2017.5
# 51     83.3  16.7        2015         2021           7            2017.2
# 52     75.0  25.0        2016         2021           6            2016.8
# 53     90.9   9.1        2016         2021           6            2010.5
# 54     54.5  45.5        2016         2021           6            2016.9
# 55     70.0  30.0        2017         2021           5            2016.6
# 56     60.0  40.0        2019         2021           3            2013.4
# 57     90.0  10.0        2017         2021           5            2015.8

# %% [markdown]
# #การวิเคราะห์เทรนด์การเพิ่มเนื้อหาเข้า **Netflix**

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 1. ลำดับการเพิ่มเนื้อหาของประเทศ
    ROW_NUMBER() OVER (
        PARTITION BY country
        ORDER BY added_year, title
    ) as addition_sequence,

    -- 2. อันดับการผลิตในปีนั้น
    DENSE_RANK() OVER (
        PARTITION BY release_year
        ORDER BY country
    ) as yearly_country_rank,

    -- 3. จำนวนเนื้อหาสะสมของประเทศ
    COUNT(*) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as cumulative_content,

    -- 4. ค่าเฉลี่ยปีการผลิตเคลื่อนที่ 5 เรื่อง
    ROUND(AVG(release_year) OVER (
        PARTITION BY country
        ORDER BY added_year
        ROWS BETWEEN 4 PRECEDING AND CURRENT ROW
    ), 1) as moving_avg_release_year,

    -- 5. ปีที่เพิ่มเนื้อหาก่อนหน้า
    LAG(added_year, 1) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as previous_addition_year,

    -- 6. ปีที่จะเพิ่มเนื้อหาถัดไป
    LEAD(added_year, 1) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as next_addition_year,

    -- 7. เนื้อหาแรกที่เพิ่มของประเทศ
    FIRST_VALUE(title) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as first_added_content,

    -- 8. เนื้อหาล่าสุดที่เพิ่มของประเทศ
    LAST_VALUE(title) OVER (
        PARTITION BY country
        ORDER BY added_year
        ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
    ) as latest_added_content,

    -- 9. อันดับการเพิ่มเนื้อหาในปีนั้นของประเทศ
    RANK() OVER (
        PARTITION BY country, added_year
        ORDER BY release_year DESC
    ) as yearly_addition_rank_by_country,

    -- 10. เปอร์เซ็นไทล์ของการเพิ่มเนื้อหาในประเทศ
    ROUND(PERCENT_RANK() OVER (
        PARTITION BY country
        ORDER BY added_year
    ), 3) as addition_percentile

FROM country_content
ORDER BY country, added_year
LIMIT 20;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#    show_id                          title            country     type  \
# 0     s366                Eyes of a Thief  , France, Algeria    Movie
# 1     s194                           D.P.      , South Korea  TV Show
# 2    s6553                      Daemonium          Argentina    Movie
# 3    s6083                       Abzurdah          Argentina    Movie
# 4    s6975            Historia de un clan          Argentina  TV Show
# 5    s5315            Todo Sobre El Asado          Argentina    Movie
# 6    s6401                Caida del Cielo          Argentina    Movie
# 7    s7035                    Hypersomnia          Argentina    Movie
# 8    s5115                         Desire          Argentina    Movie
# 9    s5552                  The Tenth Man          Argentina    Movie
# 10   s7251               La Última Fiesta          Argentina    Movie
# 11   s6005    27, el club de los malditos          Argentina    Movie
# 12   s4431                       Creators          Argentina  TV Show
# 13   s7746             Pizza, birra, faso          Argentina    Movie
# 14   s6706           Esperando La Carroza          Argentina    Movie
# 15   s7422                          Mater          Argentina    Movie
# 16   s7359  Lucha: Playing the Impossible          Argentina    Movie
# 17   s7801                    Psiconautas          Argentina  TV Show
# 18   s8186                     The Aerial          Argentina    Movie
# 19   s6483         Chronicle of an Escape          Argentina    Movie
#
#     release_year  added_year  addition_sequence  yearly_country_rank  \
# 0           2014        2021                  1                    1
# 1           2021        2021                  1                    1
# 2           2015        2016                  2                    1
# 3           2015        2016                  1                    1
# 4           2015        2017                  5                    1
# 5           2016        2017                  9                    1
# 6           2016        2017                  3                    1
# 7           2016        2017                  6                    1
# 8           2017        2017                  4                    1
# 9           2016        2017                  8                    1
# 10          2016        2017                  7                    1
# 11          2018        2018                 10                    1
# 12          2015        2018                 13                    1
# 13          1998        2018                 21                    1
# 14          1985        2018                 15                    1
# 15          2017        2018                 20                    1
# 16          2016        2018                 17                    1
# 17          2016        2018                 22                    1
# 18          2007        2018                 24                    1
# 19          2006        2018                 12                    1
#
#     cumulative_content  moving_avg_release_year  previous_addition_year  \
# 0                    1                   2014.0                    <NA>
# 1                    1                   2021.0                    <NA>
# 2                    2                   2015.0                    2016
# 3                    2                   2015.0                    <NA>
# 4                    9                   2015.6                    2017
# 5                    9                   2015.8                    2017
# 6                    9                   2015.3                    2016
# 7                    9                   2015.8                    2017
# 8                    9                   2015.8                    2017
# 9                    9                   2016.0                    2017
# 10                   9                   2016.0                    2017
# 11                  25                   2016.4                    2017
# 12                  25                   2014.6                    2018
# 13                  25                   2013.4                    2018
# 14                  25                   2008.4                    2018
# 15                  25                   2017.4                    2018
# 16                  25                   2010.4                    2018
# 17                  25                   2013.4                    2018
# 18                  25                   2011.2                    2018
# 19                  25                   2014.8                    2018
#
#     next_addition_year first_added_content latest_added_content  \
# 0                 <NA>     Eyes of a Thief      Eyes of a Thief
# 1                 <NA>                D.P.                 D.P.
# 2                 2017            Abzurdah          The Kingdom
# 3                 2016            Abzurdah          The Kingdom
# 4                 2017            Abzurdah          The Kingdom
# 5                 2018            Abzurdah          The Kingdom
# 6                 2017            Abzurdah          The Kingdom
# 7                 2017            Abzurdah          The Kingdom
# 8                 2017            Abzurdah          The Kingdom
# 9                 2017            Abzurdah          The Kingdom
# 10                2017            Abzurdah          The Kingdom
# 11                2018            Abzurdah          The Kingdom
# 12                2018            Abzurdah          The Kingdom
# 13                2018            Abzurdah          The Kingdom
# 14                2018            Abzurdah          The Kingdom
# 15                2018            Abzurdah          The Kingdom
# 16                2018            Abzurdah          The Kingdom
# 17                2018            Abzurdah          The Kingdom
# 18                2018            Abzurdah          The Kingdom
# 19                2018            Abzurdah          The Kingdom
#
#     yearly_addition_rank_by_country  addition_percentile
# 0                                 1                0.000
# 1                                 1                0.000
# 2                                 1                0.000
# 3                                 1                0.000
# 4                                 7                0.036
# 5                                 2                0.036
# 6                                 2                0.036
# 7                                 2                0.036
# 8                                 1                0.036
# 9                                 2                0.036
# 10                                2                0.036
# 11                                1                0.164
# 12                               12                0.164
# 13                               15                0.164
# 14                               16                0.164
# 15                                9                0.164
# 16                               10                0.164
# 17                               10                0.164
# 18                               13                0.164
# 19                               14                0.164

# %% [markdown]
# #ตัวอย่างแยกย่อยในแต่ละขั้นตอน

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 1. ลำดับการเพิ่มเนื้อหาของประเทศ
    ROW_NUMBER() OVER (
        PARTITION BY country
        ORDER BY added_year, title
    ) as addition_sequence,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s7035          Hypersomnia          Argentina    Movie          2016
# 5   s6401      Caida del Cielo          Argentina    Movie          2016
# 6   s7251     La Última Fiesta          Argentina    Movie          2016
# 7   s5115               Desire          Argentina    Movie          2017
# 8   s6975  Historia de un clan          Argentina  TV Show          2015
# 9   s5315  Todo Sobre El Asado          Argentina    Movie          2016
#
#    added_year  addition_sequence
# 0        2021                  1
# 1        2021                  1
# 2        2016                  2
# 3        2016                  1
# 4        2017                  6
# 5        2017                  3
# 6        2017                  7
# 7        2017                  4
# 8        2017                  5
# 9        2017                  9

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 2. อันดับการผลิตในปีนั้น
    DENSE_RANK() OVER (
        PARTITION BY release_year
        ORDER BY country
    ) as yearly_country_rank,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s5115               Desire          Argentina    Movie          2017
# 5   s7035          Hypersomnia          Argentina    Movie          2016
# 6   s6401      Caida del Cielo          Argentina    Movie          2016
# 7   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 8   s5552        The Tenth Man          Argentina    Movie          2016
# 9   s6975  Historia de un clan          Argentina  TV Show          2015
#
#    added_year  yearly_country_rank
# 0        2021                    1
# 1        2021                    1
# 2        2016                    1
# 3        2016                    1
# 4        2017                    1
# 5        2017                    1
# 6        2017                    1
# 7        2017                    1
# 8        2017                    1
# 9        2017                    1

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 3. จำนวนเนื้อหาสะสมของประเทศ
    COUNT(*) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as cumulative_content,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6083             Abzurdah          Argentina    Movie          2015
# 3   s6553            Daemonium          Argentina    Movie          2015
# 4   s5552        The Tenth Man          Argentina    Movie          2016
# 5   s7251     La Última Fiesta          Argentina    Movie          2016
# 6   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 7   s7035          Hypersomnia          Argentina    Movie          2016
# 8   s5115               Desire          Argentina    Movie          2017
# 9   s6975  Historia de un clan          Argentina  TV Show          2015
#
#    added_year  cumulative_content
# 0        2021                   1
# 1        2021                   1
# 2        2016                   2
# 3        2016                   2
# 4        2017                   9
# 5        2017                   9
# 6        2017                   9
# 7        2017                   9
# 8        2017                   9
# 9        2017                   9

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 4. ค่าเฉลี่ยปีการผลิตเคลื่อนที่ 5 เรื่อง
    ROUND(AVG(release_year) OVER (
        PARTITION BY country
        ORDER BY added_year
        ROWS BETWEEN 4 PRECEDING AND CURRENT ROW
    ), 1) as moving_avg_release_year,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6083             Abzurdah          Argentina    Movie          2015
# 3   s6553            Daemonium          Argentina    Movie          2015
# 4   s5552        The Tenth Man          Argentina    Movie          2016
# 5   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 6   s7251     La Última Fiesta          Argentina    Movie          2016
# 7   s7035          Hypersomnia          Argentina    Movie          2016
# 8   s5115               Desire          Argentina    Movie          2017
# 9   s6975  Historia de un clan          Argentina  TV Show          2015
#
#    added_year  moving_avg_release_year
# 0        2021                   2014.0
# 1        2021                   2021.0
# 2        2016                   2015.0
# 3        2016                   2015.0
# 4        2017                   2015.6
# 5        2017                   2015.3
# 6        2017                   2015.8
# 7        2017                   2016.0
# 8        2017                   2016.0
# 9        2017                   2015.8

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 5. ปีที่เพิ่มเนื้อหาก่อนหน้า
    LAG(added_year, 1) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as previous_addition_year,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6083             Abzurdah          Argentina    Movie          2015
# 3   s6553            Daemonium          Argentina    Movie          2015
# 4   s5552        The Tenth Man          Argentina    Movie          2016
# 5   s7035          Hypersomnia          Argentina    Movie          2016
# 6   s7251     La Última Fiesta          Argentina    Movie          2016
# 7   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 8   s6401      Caida del Cielo          Argentina    Movie          2016
# 9   s5115               Desire          Argentina    Movie          2017
#
#    added_year  previous_addition_year
# 0        2021                    <NA>
# 1        2021                    <NA>
# 2        2016                    <NA>
# 3        2016                    2016
# 4        2017                    2017
# 5        2017                    2017
# 6        2017                    2017
# 7        2017                    2016
# 8        2017                    2017
# 9        2017                    2017

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 6. ปีที่จะเพิ่มเนื้อหาถัดไป
    LEAD(added_year, 1) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as next_addition_year,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s7035          Hypersomnia          Argentina    Movie          2016
# 5   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 6   s6401      Caida del Cielo          Argentina    Movie          2016
# 7   s5552        The Tenth Man          Argentina    Movie          2016
# 8   s5115               Desire          Argentina    Movie          2017
# 9   s6975  Historia de un clan          Argentina  TV Show          2015
#
#    added_year  next_addition_year
# 0        2021                <NA>
# 1        2021                <NA>
# 2        2016                2017
# 3        2016                2016
# 4        2017                2017
# 5        2017                2017
# 6        2017                2017
# 7        2017                2017
# 8        2017                2018
# 9        2017                2017

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 7. เนื้อหาแรกที่เพิ่มของประเทศ
    FIRST_VALUE(title) OVER (
        PARTITION BY country
        ORDER BY added_year
    ) as first_added_content,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s5552        The Tenth Man          Argentina    Movie          2016
# 5   s7251     La Última Fiesta          Argentina    Movie          2016
# 6   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 7   s7035          Hypersomnia          Argentina    Movie          2016
# 8   s5115               Desire          Argentina    Movie          2017
# 9   s6975  Historia de un clan          Argentina  TV Show          2015
#
#    added_year first_added_content
# 0        2021     Eyes of a Thief
# 1        2021                D.P.
# 2        2016            Abzurdah
# 3        2016            Abzurdah
# 4        2017            Abzurdah
# 5        2017            Abzurdah
# 6        2017            Abzurdah
# 7        2017            Abzurdah
# 8        2017            Abzurdah
# 9        2017            Abzurdah

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 8. เนื้อหาล่าสุดที่เพิ่มของประเทศ
    LAST_VALUE(title) OVER (
        PARTITION BY country
        ORDER BY added_year
        ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING
    ) as latest_added_content,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6083             Abzurdah          Argentina    Movie          2015
# 3   s6553            Daemonium          Argentina    Movie          2015
# 4   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 5   s6401      Caida del Cielo          Argentina    Movie          2016
# 6   s5552        The Tenth Man          Argentina    Movie          2016
# 7   s7035          Hypersomnia          Argentina    Movie          2016
# 8   s5115               Desire          Argentina    Movie          2017
# 9   s7251     La Última Fiesta          Argentina    Movie          2016
#
#    added_year latest_added_content
# 0        2021      Eyes of a Thief
# 1        2021                 D.P.
# 2        2016            Al acecho
# 3        2016            Al acecho
# 4        2017            Al acecho
# 5        2017            Al acecho
# 6        2017            Al acecho
# 7        2017            Al acecho
# 8        2017            Al acecho
# 9        2017            Al acecho

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 9. อันดับการเพิ่มเนื้อหาในปีนั้นของประเทศ
    RANK() OVER (
        PARTITION BY country, added_year
        ORDER BY release_year DESC
    ) as yearly_addition_rank_by_country,

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 5   s5552        The Tenth Man          Argentina    Movie          2016
# 6   s7035          Hypersomnia          Argentina    Movie          2016
# 7   s6975  Historia de un clan          Argentina  TV Show          2015
# 8   s7251     La Última Fiesta          Argentina    Movie          2016
# 9   s6401      Caida del Cielo          Argentina    Movie          2016
#
#    added_year  yearly_addition_rank_by_country
# 0        2021                                1
# 1        2021                                1
# 2        2016                                1
# 3        2016                                1
# 4        2017                                2
# 5        2017                                2
# 6        2017                                2
# 7        2017                                7
# 8        2017                                2
# 9        2017                                2

# %%
query = """
WITH country_content AS (
    SELECT
        show_id,
        title,
        country,
        type,
        release_year,
        date_added,
        CAST(SUBSTR(date_added, -4) AS INTEGER) as added_year
    FROM netflix_result
    WHERE country IS NOT NULL AND date_added IS NOT NULL
)
SELECT
    show_id,
    title,
    country,
    type,
    release_year,
    added_year,

    -- 10. เปอร์เซ็นไทล์ของการเพิ่มเนื้อหาในประเทศ
    ROUND(PERCENT_RANK() OVER (
        PARTITION BY country
        ORDER BY added_year
    ), 3) as addition_percentile

FROM country_content
ORDER BY country, added_year
LIMIT 10;
"""

country_analysis = con.execute(query).fetchdf()
display(country_analysis)
# Out:
#   show_id                title            country     type  release_year  \
# 0    s366      Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194                 D.P.      , South Korea  TV Show          2021
# 2   s6553            Daemonium          Argentina    Movie          2015
# 3   s6083             Abzurdah          Argentina    Movie          2015
# 4   s5115               Desire          Argentina    Movie          2017
# 5   s7035          Hypersomnia          Argentina    Movie          2016
# 6   s5315  Todo Sobre El Asado          Argentina    Movie          2016
# 7   s6401      Caida del Cielo          Argentina    Movie          2016
# 8   s6975  Historia de un clan          Argentina  TV Show          2015
# 9   s7251     La Última Fiesta          Argentina    Movie          2016
#
#    added_year  addition_percentile
# 0        2021                0.000
# 1        2021                0.000
# 2        2016                0.000
# 3        2016                0.000
# 4        2017                0.036
# 5        2017                0.036
# 6        2017                0.036
# 7        2017                0.036
# 8        2017                0.036
# 9        2017                0.036

# %%
window_analysis = con.execute(query).fetchdf()

# %%
window_analysis.head()
# Out:
#   show_id            title            country     type  release_year  \
# 0    s366  Eyes of a Thief  , France, Algeria    Movie          2014
# 1    s194             D.P.      , South Korea  TV Show          2021
# 2   s6553        Daemonium          Argentina    Movie          2015
# 3   s6083         Abzurdah          Argentina    Movie          2015
# 4   s6401  Caida del Cielo          Argentina    Movie          2016
#
#    added_year  addition_sequence  yearly_country_rank  cumulative_content  \
# 0        2021                  1                    1                   1
# 1        2021                  1                    1                   1
# 2        2016                  2                    1                   2
# 3        2016                  1                    1                   2
# 4        2017                  3                    1                   9
#
#    moving_avg_release_year  previous_addition_year  next_addition_year  \
# 0                   2014.0                    <NA>                <NA>
# 1                   2021.0                    <NA>                <NA>
# 2                   2015.0                    2016                2017
# 3                   2015.0                    <NA>                2016
# 4                   2015.3                    2016                2017
#
#   first_added_content latest_added_content  yearly_addition_rank_by_country  \
# 0     Eyes of a Thief      Eyes of a Thief                                1
# 1                D.P.                 D.P.                                1
# 2            Abzurdah          The Kingdom                                1
# 3            Abzurdah          The Kingdom                                1
# 4            Abzurdah          The Kingdom                                2
#
#    addition_percentile
# 0                0.000
# 1                0.000
# 2                0.000
# 3                0.000
# 4                0.036
